# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
# <b>🥇 Станислав, спасибо за доработки, проект принят, молодец!</b>
#
# Ты провел отличную работу над ошибками! Уверен, ты обязательно достигнешь своей цели! Успехов в дальнейшем обучении! 🙂

# %% [markdown]
# Станислав, привет! Меня зовут Ефимов Денис и сегодня я буду делать ревью твоего проекта!\
# В Практикуме принято общаться на "ты", однако если это неудобно - дай знать, и можем перейти на более официальное общение.
#
# Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Если все сделано хорошо. </div>
#
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b> Некритичное замечание; если таких замечаний меньше трех — проект может быть принят без их отработки.</div>
#
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b> Грубая ошибка, необходимо исправить, иначе проект не будет принят.
# </div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# Например так:
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Hello World! ✔
# </div>
#
# Или можешь использовать эту галочку ✔ в моих комментариях, если писать особо нечего.
#
# <div class="alert alert-block alert-warning">
# <b>Общее впечатление:</b>
#
# - Ты проделал огромную работу и проект получился впечатляющим:)
# - У меня есть несколько замечаний, исправив которые ты сделаешь проект еще лучше.
# - Пробегись по моим комментариям, исправь недочёты и всё будет отлично :)
#
# </div>

# %% [markdown]
# # Выявление закономерностей, определяющие успешность игры
#
# Необходимо сделать ставку на потенциально популярный продукт и спланировать рекламные кампании.
# Перед нами данные до 2016 года. Представим, что сейчас декабрь 2016 г., и в планах кампания на 2017-й. Нужно отработать принцип работы с данными. Неважно, прогнозируете ли вы продажи на 2017 год по данным 2016-го или же 2027-й — по данным 2026 года.
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».

# %% [markdown]
# # Описание данных
# - Name — название игры
# - Platform — платформа
# - Year_of_Release — год выпуска
# - Genre — жанр игры
# - NA_sales — продажи в Северной Америке (миллионы проданных копий)
# - EU_sales — продажи в Европе (миллионы проданных копий)
# - JP_sales — продажи в Японии (миллионы проданных копий)
# - Other_sales — продажи в других странах (миллионы проданных копий)
# - Critic_Score — оценка критиков (максимум 100)
# - User_Score — оценка пользователей (максимум 10)
# - Rating — рейтинг от организации ESRB (англ. Entertainment Software Rating Board). Эта ассоциация определяет рейтинг компьютерных игр и присваивает им подходящую возрастную категорию.
#  Данные за 2016 год могут быть неполными.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец, что написал введение!  </div>

# %% [markdown]
# ## Открытие файла с данными и изучение общей информации
# Путь к файлу: /datasets/games.csv. Скачать датасет:  `https://code.s3.yandex.net/datasets/games.csv`

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Импорт всех библиотек лучше делать в одной отдельной ячейке, чтобы при необходимости можно было ее перезапустить без влияния на другой код и без перезаписи датасета. </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
#импортируем требуемые библиотека
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import seaborn as sns
from scipy import stats as st

# %%
#читаем файл
try:
    data = pd.read_csv('/datasets/games.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/games.csv')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Здорово, что используешь конструкцию try-except!  </div>

# %% [markdown]
# Открыл файл и посмотрел на общую структуру данных для анализа.

# %%
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# Вывод общей информации о таблице:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %%
data.hist(figsize=(15, 20))
plt.show()

# %% [markdown]
# **Вывод:**
# В таблице 11 колонок и 16715 строк.
# Видно что в исходных данных есть некоторые проблемы:
# - Пропуски в некоторых столбцах.
# - Не единообразный формат названий столбцов.
# - Тип данных в некотрых столбцах необзодимо поменять

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Чтобы перед графиком не выводился длинный список с параметрами, можно просто добавить строку `plt.show()` после строки построения графика. </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Каждому пункту нужен вывод.
#
# Что мы можем сказать о данных после первичного знакомства  с ними?
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ##  Подготовка данных

# %% [markdown]
# ### Замените названия столбцов (приведите к нижнему регистру);

# %%
data.columns = data.columns.str.lower()
data.head(5)
# Out:
#    index                   name platform  year_of_release     genre  na_sales  \
# 0      0             Wii Sports      Wii             2006    Sports     41.36
# 1      2         Mario Kart Wii      Wii             2008    Racing     15.68
# 2      3      Wii Sports Resort      Wii             2009    Sports     15.61
# 3      6  New Super Mario Bros.       DS             2006  Platform     11.28
# 4      7               Wii Play      Wii             2006      Misc     13.96
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  sum_sales
# 0     28.96      3.77         8.45          76.0         8.0      E      82.54
# 1     12.76      3.79         3.29          82.0         8.3      E      35.52
# 2     10.93      3.28         2.95          80.0         8.0      E      32.77
# 3      9.14      6.50         2.88          89.0         8.5      E      29.80
# 4      9.18      2.93         2.84          58.0         6.6      E      28.91

# %% [markdown]
# ### Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;

# %% [markdown]
# ### Обработайте пропуски при необходимости:

# %%
data.isna().sum()
# Out:
# name                  2
# platform              0
# year_of_release     269
# genre                 2
# na_sales              0
# eu_sales              0
# jp_sales              0
# other_sales           0
# critic_score       8578
# user_score         6701
# rating             6766
# dtype: int64

# %%
 #удаляю пропуски, количество которых не влияет на выборку
data = data.dropna(subset=['name','year_of_release','genre'])

# %%
data['year_of_release'] = data['year_of_release'].astype('int')
# Out:
# <ipython-input-10-b717bea148d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['year_of_release'] = data['year_of_release'].astype('int')

# %% [markdown]
# Удалил пропуски в столбце год выпуска. Привел данные к целочисленному значению.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b> Комментарии к исследованию лучше всегда писать в маркдаун-ячейках, зачем для этого использовать `print()`? А # обычно используется для технических пояснений к нетривиальным участкам кода</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
data['critic_score'].unique()
# Out:
# array([76., nan, 82., 80., 89., 58., 87., 91., 61., 97., 95., 77., 88.,
#        83., 94., 93., 85., 86., 98., 96., 90., 84., 73., 74., 78., 92.,
#        71., 72., 68., 62., 49., 67., 81., 66., 56., 79., 70., 59., 64.,
#        75., 60., 63., 69., 50., 25., 42., 44., 55., 48., 57., 29., 47.,
#        65., 54., 20., 53., 37., 38., 33., 52., 30., 32., 43., 45., 51.,
#        40., 46., 39., 34., 41., 36., 31., 27., 35., 26., 19., 28., 23.,
#        24., 21., 17., 13.])

# %%
data['user_score'].unique()
data.loc[data['user_score'] == 'tbd', 'user_score'] = np.nan

# заменяю на пропуск (Nan)
data['user_score'] = data['user_score'].astype('float')
data['user_score'].unique()
# Out:
# array([8. , nan, 8.3, 8.5, 6.6, 8.4, 8.6, 7.7, 6.3, 7.4, 8.2, 9. , 7.9,
#        8.1, 8.7, 7.1, 3.4, 5.3, 4.8, 3.2, 8.9, 6.4, 7.8, 7.5, 2.6, 7.2,
#        9.2, 7. , 7.3, 4.3, 7.6, 5.7, 5. , 9.1, 6.5, 8.8, 6.9, 9.4, 6.8,
#        6.1, 6.7, 5.4, 4. , 4.9, 4.5, 9.3, 6.2, 4.2, 6. , 3.7, 4.1, 5.8,
#        5.6, 5.5, 4.4, 4.6, 5.9, 3.9, 3.1, 2.9, 5.2, 3.3, 4.7, 5.1, 3.5,
#        2.5, 1.9, 3. , 2.7, 2.2, 2. , 9.5, 2.1, 3.6, 2.8, 1.8, 3.8, 0. ,
#        1.6, 9.6, 2.4, 1.7, 1.1, 0.3, 1.5, 0.7, 1.2, 2.3, 0.5, 1.3, 0.2,
#        0.6, 1.4, 0.9, 1. , 9.7])

# %% [markdown]
# В интернете нашел информацию что 'tbd' расшифровывается как "to be determined" - 'будет определенно' или "неизвестно".
# Заменил "tbd" на "nan", привел столбец к  float.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Решение заменить "tbd" на пропуски верное  </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Заполнять пропуски в оценках неверное решение) Ошибка связана с тем, что данные по оценкам не являются набором случайных наблюдений. Если бы у нас была выборка всех оценок пользователей для одной игры (один пользователь поставил оценку 10, другой 1, третий 5), то пропуски мы могли бы заменить медианой.
#
# В нашем случае оценка уже является усредненным значением выборки оценок некоторого количества пользователей. Более того, можно найти примеры, когда оценки одной игры на различных платформах отличаются в два раза.
#
# Аналогичная ситуация и с рейтингами критиков.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# Проверим еще раз пропуски

# %%
pd.DataFrame(data.isna().mean()*100).style.set_precision(1).background_gradient('coolwarm')
# Out:
# <ipython-input-13-0757890531d4>:1: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   pd.DataFrame(data.isna().mean()*100).style.set_precision(1).background_gradient('coolwarm')
# <style type="text/css">
# #T_069c3_row0_col0, #T_069c3_row1_col0, #T_069c3_row2_col0, #T_069c3_row3_col0, #T_069c3_row4_col0, #T_069c3_row5_col0, #T_069c3_row6_col0, #T_069c3_row7_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_069c3_row8_col0 {
#   background-color: #c83836;
#   color: #f1f1f1;
# }
# #T_069c3_row9_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_069c3_row10_col0 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# </style>
# <table id="T_069c3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_069c3_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# Столбец "рейтинг" оставляю с пропусками, потому что нет понимания как заполнять такие пропуски. Возможно оценки еще не были проставлены, о чем сказано в описании к данным. Также вероятно, что на момент выхода некоторых игр еще не существовало такого понятия как возрастная категория аудитории. Проверил предположение на строках с игрой Super Mario Bros.
# Удалять пропуски не буду, т.к. количество данных существенно.

# %%
data[data['name']=='Super Mario Bros.']
# Out:
#                   name platform  year_of_release     genre  na_sales  \
# 1    Super Mario Bros.      NES             1985  Platform     29.08
# 201  Super Mario Bros.       GB             1999  Platform      3.40
#
#      eu_sales  jp_sales  other_sales  critic_score  user_score rating
# 1        3.58      6.81         0.77           NaN         NaN    NaN
# 201      1.30      0.15         0.22           NaN         NaN    NaN

# %% [markdown]
# ### Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %%
data['sum_sales'] = data['na_sales'] + data['eu_sales'] + data['jp_sales'] + data['other_sales']
data['sum_sales']
# Out:
# 0        82.54
# 1        40.24
# 2        35.52
# 3        32.77
# 4        31.38
#          ...
# 16710     0.01
# 16711     0.01
# 16712     0.01
# 16713     0.01
# 16714     0.01
# Name: sum_sales, Length: 16444, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Еще тут можно использовать метод `DataFrame.sum` с аргументом `axis=1`</div>
#
# ```python
#
#         df['total_sum'] = df[['value_1', 'value_2', 'value_3', 'value_4']].sum(axis=1)
#
# ```

# %% [markdown]
# Проверим также на явные дубликаты

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Провел предобработку данных.**
# - Привел названия столбцов к нижнему регистру.
# - Удалили строки с пропусками, количество которых не влияет на результаты исследования.
# - Преобразовал тип данных:
#  - Год выпуска привел к целочисленному значению.
#  - Оценку пользователей к дробному.
# - В данных со столбцом было значение "tbd". Выяснил что это расшифровывается как "to be determined" - 'будет определенно' или "неизвестно". Заменил на `nan`.
#
# Столбцы с рейтингами и оценками критиков и пользователей оставляю с пропусками, потому что нет понимания как заполнять такие пропуски. Возможно оценки еще не были проставлены, о чем сказано в описании к данным. Также вероятно, что на момент выхода некоторых игр еще не существовало такого понятия как возрастная категория аудитории.
# - Создал столбец с общей суммой продаж.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# После этапа предобработки также нужно сделать краткий резюмирующий вывод о проделанной работе.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %%
data.head(5)
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score rating  sum_sales
# 0     28.96      3.77         8.45          76.0         8.0      E      82.54
# 1      3.58      6.81         0.77           NaN         NaN    NaN      40.24
# 2     12.76      3.79         3.29          82.0         8.3      E      35.52
# 3     10.93      3.28         2.95          80.0         8.0      E      32.77
# 4      8.89     10.22         1.00           NaN         NaN    NaN      31.38

# %% [markdown]
# ### Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
count_year = data.pivot_table(index='year_of_release', values='name', aggfunc='count')
count_year
# Out:
#                  name
# year_of_release
# 1980                9
# 1981               46
# 1982               36
# 1983               17
# 1984               14
# 1985               14
# 1986               21
# 1987               16
# 1988               15
# 1989               17
# 1990               16
# 1991               41
# 1992               43
# 1993               60
# 1994              121
# 1995              219
# 1996              263
# 1997              289
# 1998              379
# 1999              338
# 2000              350
# 2001              482
# 2002              829
# 2003              775
# 2004              762
# 2005              939
# 2006             1006
# 2007             1197
# 2008             1427
# 2009             1426
# 2010             1255
# 2011             1136
# 2012              653
# 2013              544
# 2014              581
# 2015              606
# 2016              502

# %%
count_year.plot(kind='bar',  figsize=(15,6))
plt.title('Сколько игр выпускалось в разные годы')
plt.ylabel('Количество')
plt.xlabel('Год выпуска')
plt.show()

# %%
data
# Out:
#                                 name platform  year_of_release         genre  \
# 0                         Wii Sports      Wii             2006        Sports
# 1                  Super Mario Bros.      NES             1985      Platform
# 2                     Mario Kart Wii      Wii             2008        Racing
# 3                  Wii Sports Resort      Wii             2009        Sports
# 4           Pokemon Red/Pokemon Blue       GB             1996  Role-Playing
# ...                              ...      ...              ...           ...
# 16710  Samurai Warriors: Sanada Maru      PS3             2016        Action
# 16711               LMA Manager 2007     X360             2006        Sports
# 16712        Haitaka no Psychedelica      PSV             2016     Adventure
# 16713               Spirits & Spells      GBA             2003      Platform
# 16714            Winning Post 8 2016      PSV             2016    Simulation
#
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец ,что подписываешь графики и оси! </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Тут лучше выбрать другой тип графика с предварительной группировкой по годам и подсчетом количества игр.
#
# Что за всплеск около 2015 года? Есть ли он на самом деле?</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# Из графика видно, что пик приходится на 2008 и 2009 года. Можно сделать вывод, что данные до 2002 года можно не принимать в расчет.

# %%
data = data[data['year_of_release'] > 2001].reset_index()

# %%
count_year_after2002 = data.pivot_table(index='year_of_release', values='platform', aggfunc='count')
count_year_after2002.plot(kind='bar',  figsize=(15,6))
plt.title('Сколько игр выпускалось после 2002 года')
plt.ylabel('Количество')
plt.xlabel('Год выпуска')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Тут аналогично</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ### Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %% [markdown]
# Наиболее популярные платформы:

# %%
#для анализа взял 10 самых продаваемых платформ
ten_platform = data.pivot_table(index = 'platform', values = 'sum_sales', \
                                aggfunc='sum').sort_values(by = 'sum_sales', ascending = False).head(10).round(2)
ten_platform.plot(kind='bar',y = 'sum_sales',figsize=(15,6))
plt.title('Наиболее популярные платформы:')
plt.xlabel("Платформа")
plt.ylabel("Продажи")
plt.show()
ten_platform
# Out:
#           sum_sales
# platform
# PS2         1027.96
# X360         961.24
# PS3          931.34
# Wii          891.18
# DS           802.76
# PS4          314.14
# PSP          289.53
# 3DS          257.81
# GBA          251.28
# XB           228.32

# %% [markdown]
# Отдельное распределение по годам:

# %%
#Получим список названий платформ
ten_platform_name = list(ten_platform.index)

#Построим графики распределения по годам
for i in ten_platform_name:
    data[data['platform'] == i].pivot_table(index = 'year_of_release', \
                                            values = 'sum_sales', aggfunc = 'sum').plot(kind = 'bar', figsize=(15,5))
    plt.title(i)
    plt.xlabel("Год")
    plt.ylabel("Продажи")
    plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Молодец ,что использовал цикл! </div>

# %% [markdown]
# Из графиков видно, что средняя продолжительнось максимальных продаж платформы составляет около 6 лет.

# %% [markdown]
# ### Возьмите данные за соответствующий актуальный период. Актуальный период определите самостоятельно в результате исследования предыдущих вопросов. Основной фактор — эти данные помогут построить прогноз на 2017 год.

# %% [markdown]
# Исходя из среднего характерного срока актуальности платформ - 6 лет и динамично развивающейся игровой индустрии, предположу что актуальные данные необходимо брать с 2014 года, т.к. на 2016 придется рост продаж.
# По этим данным можно предположить что будет актуально на 2017 год.

# %% [markdown]
# ### Не учитывайте в работе данные за предыдущие годы.

# %%
data_after_2014 = data[data['year_of_release'] >= 2014].reset_index(drop=True)

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Ты все отлично проанализировал и объяснил, но актуальный период выбрал немного больше чем нужно. В этот срез могут попасть уже неактуальные платформы.
#
# Учитывая высокую динамичность рынка, мы можем сделать вывод, что для дальнейшего анализа нам потребуются данные по платформам, возникшим не ранее 3 лет назад по отношению к 2017 году, на который нам нужно сделать прогноз и запланировать рекламные кампании. Так мы сможем выделить успешные платформы, которые на 2017 год будут находиться в периоде финального роста или выйдут на плато. </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
data_after_2014
# Out:
#       index                                       name platform  \
# 0        31                  Call of Duty: Black Ops 3      PS4
# 1        42                         Grand Theft Auto V      PS4
# 2        47  Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS
# 3        77                                    FIFA 16      PS4
# 4        87               Star Wars Battlefront (2015)      PS4
# ...     ...                                        ...      ...
# 1684  16703                           Strawberry Nauts      PSV
# 1685  16707                           Aiyoku no Eustia      PSV
# 1686  16710              Samurai Warriors: Sanada Maru      PS3
# 1687  16712                    Haitaka no Psychedelica      PSV
# 1688  16714                        Winning Post 8 2016      PSV
#
#       year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 0                2015       Shooter      6.03      5.86      0.36
# ...

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.

# %%
#Получим список названий платформ
platform_name = list(data_after_2014['platform'].unique())

#Построим графики распределения по годам
for j in platform_name:
    data_after_2014[data_after_2014['platform'] == j].pivot_table(index = 'year_of_release', \
                                            values = 'sum_sales', aggfunc = 'sum').plot(kind = 'bar', figsize=(10,5))
    plt.title(j)
    plt.xlabel("Год")
    plt.ylabel("Продажи")
    plt.show()

# %% [markdown]
# Потенциально прибыльные площадки: PS4 и XOne. Также показатели продаж PC показывают стабильные результаты, считаю что эту платформу также следует расматривать.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Платформу Wii разве можно отнести к потенциально прибыльным? 3DS тоже под сомнением.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
#создадим список с названиями этих платформ
profit_platform_name = ['PS4', 'XOne', 'PC']

# %% [markdown]
# ### Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %%
data_after_2014
# Out:
#       index                                       name platform  \
# 0        31                  Call of Duty: Black Ops 3      PS4
# 1        42                         Grand Theft Auto V      PS4
# 2        47  Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS
# 3        77                                    FIFA 16      PS4
# 4        87               Star Wars Battlefront (2015)      PS4
# ...     ...                                        ...      ...
# 1684  16703                           Strawberry Nauts      PSV
# 1685  16707                           Aiyoku no Eustia      PSV
# 1686  16710              Samurai Warriors: Sanada Maru      PS3
# 1687  16712                    Haitaka no Psychedelica      PSV
# 1688  16714                        Winning Post 8 2016      PSV
#
#       year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 0                2015       Shooter      6.03      5.86      0.36
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Далее нам нужно анализировать все данные из актуального периода, без дополнительных фильтраций по платформам. Это позволит нам убедиться в правильности выбора перспективных платформ и не допустить ошибок.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
#
# Воспользовался твоей подсказкой, такое решение гораздо наглядней.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
plt.figure(figsize=(17, 11))
sns.boxplot(data=data_after_2014, y='platform', x='sum_sales')
plt.xlim(-0.1, 5)

plt.title('Объемы продаж игр на разных платформах', size=17)
plt.xlabel('Объем продаж', size=12)
plt.ylabel('Название платформы', size=12)

plt.show()

# %% [markdown]
#  - Из графика видно что больше всего выбросов в результатах у платформ 'PS4' и '3DS', выбросов меньше у 'Wii' и 'PC'.
#  - Самые большие продажи у 'PS4', 'Wii' и XOne.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Для удобства можно расположить диаграммы горизонтально (пример ниже). Для визуализации мне больше нравится библиотека seaborn. Есть [отличная статья](https://habr.com/ru/post/468295/), где показаны различные способы визуализации. Может быть тебе пригодится)</div>

# %%
# код ревьюера

import seaborn as sns

plt.figure(figsize=(17, 11))
sns.boxplot(data=data_after_2014, y='platform', x='sum_sales')
plt.xlim(-0.1, 5)

plt.title('Объемы продаж игр на разных платформах', size=17)
plt.xlabel('Объем продаж', size=12)
plt.ylabel('Название платформы', size=12)

plt.show()

# %% [markdown]
# ### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %% [markdown]
# Посмотрим на примере 'PS4', т.к. она является наиболе популярной.

# %%
data_ps4 = data_after_2014[(data_after_2014['platform'] == 'PS4')]
data_ps4
# Out:
#       index                            name platform  year_of_release  \
# 0        31       Call of Duty: Black Ops 3      PS4             2015
# 1        42              Grand Theft Auto V      PS4             2014
# 3        77                         FIFA 16      PS4             2015
# 4        87    Star Wars Battlefront (2015)      PS4             2015
# 5        92  Call of Duty: Advanced Warfare      PS4             2014
# ...     ...                             ...      ...              ...
# 1627  16500                     Root Letter      PS4             2016
# 1629  16503               Shin Hayarigami 2      PS4             2016
# 1636  16526                      Dungeons 2      PS4             2016
# 1637  16530         Carmageddon: Max Damage      PS4             2016
# 1651  16585   Farming 2017 - The Simulation      PS4             2016
#
#              genre  na_sales  eu_sales  jp_sales  other_sales  critic_score  \
# ...

# %%
data_ps4.plot(x='critic_score', y='sum_sales',grid=True, kind='scatter', alpha=0.35,figsize=(10,7))
plt.title('Диаграмма рассеяния для PS4')
plt.ylabel('Сумма продаж')
plt.xlabel('Оценка критиков')
plt.show()
data_ps4['critic_score'].corr(data_ps4['sum_sales']).round(3)
# Out:
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# 0.403

# %%
data_ps4.plot(x='user_score', y='sum_sales',grid=True, kind='scatter', alpha=0.35,figsize=(10,7))
plt.title('Диаграмма рассеяния для PS4')
plt.ylabel('Сумма продаж')
plt.xlabel('Оценка пользователей')
plt.show()
data_ps4['user_score'].corr(data_ps4['sum_sales']).round(3)
# Out:
# -0.04

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Названия для графиков всегда следует подписывать  </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера 2:</b>
#
# Стоит в названии уточнить, что это за  "Диаграмма рассеяния", добавив название платформы </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# Зависимость между оценкой критиков гораздо выше, чем оценка пользователей, 0.34 против 0.06.
# Однако покатель кореляции невысокий и нельзя однозначно сказать что есть зависимость.

# %% [markdown]
# ### Соотнесите выводы с продажами игр на других платформах.

# %%
#построим графики рассеивания для других платформ profit_platform_name = ['PS4', 'XOne', 'PC']

for i in profit_platform_name[1:]:
    data_after_2014[(data_after_2014['platform'] == i)].plot(x='critic_score', \
                                                             y='sum_sales',grid=True, kind='scatter',\
                                                             alpha=0.35,figsize=(10,8)) 
    plt.ylabel('Сумма продаж')
    plt.xlabel('Оценка критиков')
    plt.title(i)
    plt.show()
    print('Показатель кореляции: ',  data_after_2014[(data_after_2014['platform']== i)]\
          ['critic_score'].corr(data_after_2014['sum_sales']).round(3))
    
    data_after_2014[(data_after_2014['platform'] == i)].plot(x='user_score', \
                                                             y='sum_sales',grid=True, kind='scatter',\
                                                             alpha=0.35,figsize=(10,8)) 
    plt.ylabel('Сумма продаж')
    plt.xlabel('Оценка пользователей')
    plt.title(i)
    plt.show()
    print('Показатель кореляции: ',  data_after_2014[(data_after_2014['platform']== i)]\
          ['user_score'].corr(data_after_2014['sum_sales']).round(3))
# Out:
# Показатель кореляции:  0.429
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Показатель кореляции:  -0.07
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Показатель кореляции:  0.175
# /usr/local/lib/python3.9/dist-packages/pandas/plotting/_matplotlib/core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# Показатель кореляции:  -0.072

# %% [markdown]
# По графику можно сделать следующий вывод:
# - В целом показатель кореляции для оценки критиков выше чем для оценки пользователей, что говорит о том что оценки критиков важнее.
# - Связь между оценками критиков и продажами все же "умеренная".
# - Наиболее влияют оценки критиков на такие платформы как:
#  + 'PS4' и 'XOne'.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Зависимость продаж от оценок пользователей и критиков проанализирована верно! </div>

# %% [markdown]
# ### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
profit_genre = data_after_2014.pivot_table(index='genre', values='sum_sales', aggfunc='median').sort_values(
    by='sum_sales', ascending=False).reset_index()
profit_genre
# Out:
#            genre  sum_sales
# 0        Shooter      0.515
# 1         Sports      0.180
# 2       Platform      0.140
# 3       Fighting      0.125
# 4   Role-Playing      0.110
# 5     Simulation      0.100
# 6         Action      0.090
# 7           Misc      0.090
# 8         Racing      0.090
# 9       Strategy      0.060
# 10        Puzzle      0.045
# 11     Adventure      0.030

# %%
profit_genre.plot(kind='bar',y = 'sum_sales', x ='genre', figsize=(15,6))
plt.title('Общее распределение игр по жанрам')
plt.ylabel('Сумма продаж')
plt.xlabel('Жанр')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Определять прибыльность жанров только по суммарным продажам не совсем корректно, нужно еще учитывать соотношение с количеством выпущенных игр. А лучше сразу рассматривать медианные значения продаж, они являются наиболее объективным показателем прибыльности, так как менее подвержены влиянию выбросов (а в игровой индустрии их достаточно много за счет продаж очень популярных и хитовых игр)</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# Наиболее выделются:
# - Самые большие продажи у жанра `Shooter`.
# - Наименьшей показатель - `Adventure`.
#
# Самые  прибыльные жанры:
# - Shooter
# - Sports
# - Platform

# %% [markdown]
# **Общий вывод по разделу:**
# - Средняя продолжительность жизни платформы - 6 лет.
# - Для компьютера показатели хоть и не самые высокие, но постоянно стабильные, что говорит об универсальности.
# - Потенциально прибыльные площадки: PS4, XOne.
# - В незначительной степени на продажи влияют оценки критиков.
# - Самые  прибыльные жанры:
#     - Shooter
#     - Sports
#     - Platform

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Здорово, что не забываешь писать промежуточные выводы </div>

# %% [markdown]
# ## Портрет пользователя каждого региона

# %% [markdown]
# ### Определите для пользователя каждого региона (NA, EU, JP):
#
# **Самые популярные платформы (топ-5). Опишите различия в долях продаж.**

# %%
#Самые популярные платформы (топ-5) na
top5_platform_na = data_after_2014.groupby('platform')['na_sales'].sum().sort_values(ascending=False).head(5)
top5_platform_na
# Out:
# platform
# PS4     98.61
# XOne    81.27
# X360    28.30
# 3DS     22.64
# PS3     22.05
# Name: na_sales, dtype: float64

# %%
top5_platform_na.plot(kind='bar',y = 'na_sales', x ='platform', figsize=(15,6))
plt.title('Продажи в Северной Америке')
plt.ylabel('Сумма продаж')
plt.xlabel('Платформа')
plt.show()

# %% [markdown]
# Для региона Северная Америка наиболее продаваемая платформа - PS4.

# %%
#Самые популярные платформы (топ-5) eu
top5_platform_eu = data_after_2014.groupby('platform')['eu_sales'].sum().sort_values(ascending=False).head(5)
top5_platform_eu
# Out:
# platform
# PS4     130.04
# XOne     46.25
# PS3      25.54
# PC       17.97
# 3DS      16.12
# Name: eu_sales, dtype: float64

# %%
top5_platform_eu.plot(kind='bar',y = 'eu_sales', x ='platform', figsize=(15,6))
plt.title('Продажи в Европе')
plt.ylabel('Сумма продаж')
plt.xlabel('Платформа')
plt.show()

# %% [markdown]
# Для региона Европа наиболее продаваемая платформа - PS4.

# %%
#Самые популярные платформы (топ-5) eu
top5_platform_jp = data_after_2014.groupby('platform')['jp_sales'].sum().sort_values(ascending=False).head(5)
top5_platform_jp
# Out:
# platform
# 3DS     44.24
# PS4     15.02
# PSV     14.54
# PS3     11.22
# WiiU     7.31
# Name: jp_sales, dtype: float64

# %%
top5_platform_jp.plot(kind='bar',y = 'jp_sales', x ='platform', figsize=(15,6))
plt.title('Продажи в Японии')
plt.ylabel('Сумма продаж')
plt.xlabel('Платформа')
plt.show()

# %% [markdown]
# Для Японии наиболее продаваемая платформа - 3DS.

# %% [markdown]
# ### **Самые популярные жанры (топ-5). Поясните разницу.**

# %%
data_after_2014
# Out:
#       index                                       name platform  \
# 0        31                  Call of Duty: Black Ops 3      PS4
# 1        42                         Grand Theft Auto V      PS4
# 2        47  Pokemon Omega Ruby/Pokemon Alpha Sapphire      3DS
# 3        77                                    FIFA 16      PS4
# 4        87               Star Wars Battlefront (2015)      PS4
# ...     ...                                        ...      ...
# 1684  16703                           Strawberry Nauts      PSV
# 1685  16707                           Aiyoku no Eustia      PSV
# 1686  16710              Samurai Warriors: Sanada Maru      PS3
# 1687  16712                    Haitaka no Psychedelica      PSV
# 1688  16714                        Winning Post 8 2016      PSV
#
#       year_of_release         genre  na_sales  eu_sales  jp_sales  \
# 0                2015       Shooter      6.03      5.86      0.36
# ...

# %%
#Самые популярные жанры (топ-5) na
top5_genre_na = data_after_2014.groupby('genre')['na_sales'].sum().sort_values(ascending=False).head(5)
top5_genre_na
# Out:
# genre
# Shooter         79.02
# Action          72.53
# Sports          46.13
# Role-Playing    33.47
# Misc            15.05
# Name: na_sales, dtype: float64

# %%
top5_genre_na.plot(kind='bar',y = 'na_sales', x ='genre', figsize=(15,6))
plt.title('Продажи в Северной Америке')
plt.ylabel('Сумма продаж')
plt.xlabel('Жанр')
plt.show()

# %% [markdown]
# Самый популярный жанр для региона Северная Америка - `Shooter`.

# %%
#Самые популярные жанры (топ-5) eu
top5_genre_eu = data_after_2014.groupby('genre')['eu_sales'].sum().sort_values(ascending=False).head(5)
top5_genre_eu
# Out:
# genre
# Action          74.68
# Shooter         65.52
# Sports          45.73
# Role-Playing    28.17
# Racing          14.13
# Name: eu_sales, dtype: float64

# %%
top5_genre_eu.plot(kind='bar',y = 'eu_sales', x ='genre', figsize=(15,6))
plt.title('Продажи в Европе')
plt.ylabel('Сумма продаж')
plt.xlabel('Жанр')
plt.show()

# %% [markdown]
# Самый популярный жанр для региона Европа - `Action`.

# %%
#Самые популярные жанры (топ-5) jp
top5_genre_jp = data_after_2014.groupby('genre')['jp_sales'].sum().sort_values(ascending=False).head(5)
top5_genre_jp
# Out:
# genre
# Role-Playing    31.16
# Action          29.58
# Fighting         6.37
# Misc             5.61
# Shooter          4.87
# Name: jp_sales, dtype: float64

# %%
top5_genre_jp.plot(kind='bar',y = 'jp_sales', x ='genre', figsize=(15,6))
plt.title('Продажи в Японии')
plt.ylabel('Сумма продаж')
plt.xlabel('Жанр')
plt.show()

# %% [markdown]
# Самый популярный жанр для Японии - `Role-Playing` и `Action`. На мой взгдяд это связано с особенностями богатой, и немного самобытной местной культуры.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Ты абсолютно верно все сделал, построил подходящие визуализации, но результаты мы получили не совсем верные из-за некорректного актуального периода. После его изменения нужно будет подправить выводы в соответствии с новыми результатами.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ### **Влияет ли рейтинг ESRB на продажи в отдельном регионе?**

# %%
#влияние рейтинга ESRB na
top5_rating_na = data_after_2014.groupby('rating')['na_sales'].sum().sort_values(ascending=False).head(5)
top5_rating_na
# Out:
# rating
# M       96.42
# E       50.74
# T       38.95
# E10+    33.23
# Name: na_sales, dtype: float64

# %%
top5_rating_na.plot(kind='bar',y = 'na_sales', x ='rating', figsize=(15,6))
plt.title('Популярность игр с рейтингом в Северной Америке')
plt.ylabel('Сумма продаж')
plt.xlabel('Рейтинг')
plt.show()

# %% [markdown]
# Данные с Вики:
#
# «M» («Mature») — «Для взрослых»: Материалы игры не подходят для лиц младше 17 лет. Проекты с данным рейтингом могут содержать достаточно жестокое насилие, большое количество крови с расчленением, непристойные сексуальные сцены или грубую ненормативную лексику, нежелательную для младшей аудитории.

# %% [markdown]
# Для Северной Америки популярны игры с рейтингом М.

# %%
#влияние рейтинга ESRB eu
top5_rating_eu = data_after_2014.groupby('rating')['eu_sales'].sum().sort_values(ascending=False).head(5)
top5_rating_eu
# Out:
# rating
# M       93.44
# E       58.06
# T       34.07
# E10+    26.16
# Name: eu_sales, dtype: float64

# %%
top5_rating_eu.plot(kind='bar',y = 'eu_sales', x ='rating', figsize=(15,6))
plt.title('Популярность игр с рейтингом в Европе')
plt.ylabel('Сумма продаж')
plt.xlabel('Рейтинг')
plt.show()

# %% [markdown]
# Для Европы также популярны игры с рейтингом М.

# %%
#влияние рейтинга ESRB jp
top5_rating_jp = data_after_2014.groupby('rating')['jp_sales'].sum().sort_values(ascending=False).head(5)
top5_rating_jp
# Out:
# rating
# T       14.78
# E        8.94
# M        8.01
# E10+     4.46
# Name: jp_sales, dtype: float64

# %%
top5_rating_jp.plot(kind='bar',y = 'jp_sales', x ='rating', figsize=(15,6))
plt.title('Популярность игр с рейтингом в Японии')
plt.ylabel('Сумма продаж')
plt.xlabel('Рейтинг')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# А если заполнить пропуски в рейтингах каким-нибудь единым значением, означающим отсутствие рейтинга, то можно будет увидеть интересную особенность)</div>

# %% [markdown]
# Данные с Вики:
#
# «E» («Everyone») — «Для всех»: Содержание вполне подходит для всех возрастов. Такие игры могут понравиться и взрослым. Игры с этим рейтингом могут содержать минимальное насилие, в основном «мультяшного» характера.
#
#
# «T» («Teen») — «Подросткам»: Игра подходит для лиц от 13 лет. Проекты из данной категории могут содержать насилие, непристойные сцены, грубый юмор, в меру откровенное сексуальное содержимое, кровь или нечастое использование ненормативной лексики.

# %% [markdown]
# Для Японии и в этом случае наблюдается особенности культуры и ее восприятие. Самый популярный рейтинг «T» («Teen») — «Подросткам»

# %% [markdown]
# Выводы:
# - В разных регионах различаются  популярные платформы.
#  - Для Северной Америки и Европы это `PS4`
#  - Для Японии - `3DS`
# - В представленных регионах популярные жанры также отличаются, однако для Северной Америки они такие же как и во всем мире, лидирует жанр - `Shooter`. Для Европы популярный жанр - `Action`.В Японии самый популярный жанр - `Role-Playing`.
# - Рейтинг ESRB влияет на продажи в разных регионах. Для Северной Америки и Европы популярные игры с ограничением "М" и "Е".
# - В Японии популярны игры с рейтингом "Т" и "E".
# Данные особенности нужно учитывать при выборе целевой аудитории.

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# Алгоритм проверки статистических гипотез всегда начинается с
# формулирования гипотез. Сначала формулируется нулевая гипотеза H₀.
# Например, «среднее рассматриваемой генеральной совокупности равно
# A», где А — некоторое число. Исходя из H₀ формулируется
# альтернативная гипотеза H₁. Для этой H₀ она звучит как «среднее
# генеральной совокупности не равно A». H₀ всегда формулируется так,
# чтобы использовать знак равенства.
# Уровень статистической значимости принимаем 5% - общепринятое значение.

# %% [markdown]
# ### Гипотеза №1

# %% [markdown]
# H₀ - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые.
#
# H₁ - Средние пользовательские рейтинги платформ Xbox One и PC различаются.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Здорово, что формулируешь гипотезы вначале шага </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>🔁Комментарий ревьюера:</b>
#
# Все библиотеки лучше импортировать в самом начале проекта, в отдельной ячейке. Если в процессе работы появилась необходимость добавить библиотеку, то ее можно дописать в эту ячейку и исполнить.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
score_xone = data_after_2014.query('platform == "XOne"')['user_score']
score_pc = data_after_2014.query('platform == "PC" ')['user_score']

alpha = 0.05 # задайте уровень статистической значимости

results = st.ttest_ind(score_xone, score_pc, nan_policy='omit')  # проведите тест здесь

# выведите на экран полученное p-значение
print('p-значение:', results.pvalue.round(3))

if results.pvalue<alpha: # сравните p-значение с заданным уровнем стат. значимости
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 0.105
# Не получилось отвергнуть нулевую гипотезу

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b> Круто, что используешь аргумент nan_policy вместо удаления или фильтрации пропусков! </div>

# %% [markdown]
# **С большой долей вероятности средние пользовательские рейтинги платформ XOne и PC не имеют статистически значимых отличий.**

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Мы не можем подтвердить гипотезу и сказать, что средние пользовательские рейтинги платформ Xbox One и PC одинаковые (можешь убедиться, что они разные). Мы лишь говорим ,что не можем отвергнуть нулевую гипотезу и что с большой долей вероятности средние пользовательские рейтинги платформ XOne и PC не имеют статистически значимых отличий. Это касается первой гипотезы.
#
# Давай аналогично сформулируем вывод для второй гипотезы.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %% [markdown]
# ### Гипотеза №2
# H₀ - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») одинаковые.
# H₁ - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>❌Комментарий ревьюера:</b>
#
# Нулевая гипотеза всегда формулируется исходя из равенства сравниваемых метрик (как в первой гипотезе). У тебя формулировка некорректная, поэтому и получили неверный результат.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>🔄Комментарий студента:</b>
# Готово! ✔
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера 2:</b> Отлично, исправлено!👍  </div>

# %%
score_action = data_after_2014.query('genre == "Action"')['user_score']
score_sports = data_after_2014.query('genre == "Sports" ')['user_score']

alpha = 0.05 # задайте уровень статистической значимости

results = st.ttest_ind(score_action, score_sports, nan_policy='omit')  # проведите тест здесь

# выведите на экран полученное p-значение
print('p-значение:', results.pvalue)

if results.pvalue<alpha: # сравните p-значение с заданным уровнем стат. значимости
    print('Отвергаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# p-значение: 2.8711147985107304e-19
# Отвергаем нулевую гипотезу

# %% [markdown]
# **С большой долей вероятности средние пользовательские рейтинги жанров Action и Sports имеют статистически значимые отличия.**

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# **Был проведен анализ данных о продажах игр. Главной целью задания было выявить потенциально прибыльные площадки.**
# Был изучен датасет с данныи о продажах за прошлые годы.
# Произведена подготовка данных:
# - Замена названий столбцов и приведение данных к общему виду
# - Преобразованы типы данных в определенных стлобцах для дальнейшей корректной работы с ними.
# - Обработаны пропуски там где это возможно. Заполнены в основном медианой, т.к. она более правильно отражает средние данные.
# - Посчитаны суммарные продажи по предсавленным регионам (Северная Америка, Европа, Япония и остальные).
#
# Провел исследовательский анализ данных, из которого сделаны выводы:
# - Средняя продолжительность жизни платформы около 6 лет.
# - В свзяи этими данными и динамично развивающейся игровой индустрией, взял для анализа данные с 2014, чтобы на их основании выявить тенденции роста продаж и прибыли.
# - Самыми перспективными платформами на момент проведения анализа, а это конец 2016 года, являются PS4 и XOne, а также PC.
# - Выяснил что отзывы критиков имеют небольшое вляиение на продажи, отызывы же пользователей никакого влияния не имеют.
# - Продажи внутри платформы PS4 в целом повторяют общую тенденцию.
# - Самая прибыльный жанр - `Shooter`.
# - Самая продаваемая возрастная категория игр -  "М" и "Е".
# - Если делать упор на японский рынок, то нужно присмотреться к жанру `Role-Playing`, платформе `3DS` и возрастной категории - "Т" и "Е".
#
# Проверил гипотезы и определил, что:
# - С большой долей вероятности средние пользовательские рейтинги платформ XOne и PC не имеют статистически значимых отличий.
# - С большой долей вероятности средние пользовательские рейтинги жанров Action и Sports имеют статистически значимые отличия.
#
# **По итогам анализа предлагаю рассматривать как потенциально прибыльные платформы на 2017 год: PS4, XOne и PC.
# Актуальный игровой жанр - `Shooter`.**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>✅Комментарий ревьюера:</b>
#
# Хороший резюмирующий вывод! Молодец, что не забыл дать рекомендации на 2017 год.
#
#
# Хочу обратить твое внимание на то, что после исправления замечаний в некоторых пунктах исследования могут измениться результаты, поэтому нужно будет подкорректировать выводы. </div>
