# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
# <b>Привет, Станислав!👋</b>
#
# Меня зовут Ольга Вишневская, я буду проверять твой проект. Предлагаю общаться на "ты", но если тебе не удобно, пожалуйста дай знать. Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе в учебе.
#
#
# Ты можешь найти мои комментарии, обозначенные <font color='green'>зеленым</font>, <font color='gold'>желтым</font> и <font color='red'>красным</font> цветами, например:
#
# <p>
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# Так выделены самые важные замечания. Без их отработки я не смогу принять проект. </div>
#
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
# Так выделены небольшие замечания. Не более трёх таких замечаний допустимы. Если их много - постарайся исправить их.</div>
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Так выделены все остальные комментарии.</div>
#
# Пожалуйста, <b>не перемещай, не изменяй и не удаляй мои комментарии</b>, они будут особенно полезны для нашей работы в случае повторной проверки проекта.
# Предлагаю работать в диалоге: если что-то дорабатываешь или отвечаешь на мой комментарий - пиши об этом и мне будет удобней, если ты выделишь свои комментарии:
# <p>
# <div class="alert-info">
# <b>Комментарий студента</b>
#
# Например, так.</div>
#
# Увидев у тебя неточность, в первый раз я лишь укажу на ее наличие и дам тебе возможность самому найти и исправить ее. На реальной работе твой руководитель будет поступать также. Но если ты пока не справишься с такой задачей - при следующей проверке я дам более точную подсказку!🤓

# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
# <p>
# <div class="alert-success">
#
# Добрый вечер, Станислав! Новые комментарии я буду помечать вот так:
# <b>Комментарий ревьюера 2</b>

# %% [markdown]
# # Исследование надежности заемщиков

# %% [markdown]
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Первая часть автоматизирвана, но я оставлю несколько комментариев по ней, чтобы тебе было проще выполнять следующие проекты. Я выделю их зеленым. Пожалуйста, обрати на них внимание. Обработка на твое усмотрение.

# %% [markdown]
# Во второй части проекта вы выполните шаги 3 и 4. Их вручную проверит ревьюер.
# Чтобы вам не пришлось писать код заново для шагов 1 и 2, мы добавили авторские решения в ячейки с кодом.

# %% [markdown]
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Вступление станет лучше, если ты добавишь в него краткое описание проекта, цель проекта, план работы и описание данных, тогда получатель отчета сможет быстрей его понять.
#
#
#
# Пример описания данных:
# - *airports_nearest* — расстояние до ближайшего аэропорта в метрах (м)
# - *balcony* — число балконов
# - ...
#
#
# Твой проект станет намного удобней в использовании, если ты добавишь интерактивное оглавление — с помощью гиперссылок или в плагине toc. Материал об этом есть в блоке курса Полезные инструкции для учёбы - Оформление проекта - Изменения в Jupyter: автоматическое оглавление и горячие клавиши.

# %% [markdown]
# <p>
# <div class="alert-info">
#
# *data* — Исследование надежности заемщиков

# %% [markdown]
# ## Откройте таблицу и изучите общую информацию о данных

# %% [markdown]
# **Задание 1. Импортируйте библиотеку pandas. Считайте данные из csv-файла в датафрейм и сохраните в переменную `data`. Путь к файлу:**
#
# `/datasets/data.csv`

# %%
import pandas as pd

try:
    data = pd.read_csv('/datasets/data.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/data.csv')

# %% [markdown]
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
#
# Блок загрузки библиотек лучше размещать в отдельной от остального кода ячейке. Такой подход позволит улучшить читаемость кода, снизит время поиска ошибок (если они есть) и исключит повторное выполнение кода.
#
# Здорово, что здесь используется конструкция ``try-except`` для путей файлов. Но еще лучше использовать библиотеку ``os``:
#
#     import os
#
#     pth1 = '/folder_1/data.csv'
#     pth2 = '/folder_2/data.csv'
#
#     if os.path.exists(pth1):
#         query_1 = pd.read_csv(pth1)
#     elif os.path.exists(pth2):
#         query_1 = pd.read_csv(pth2)
#     else:
#         print('Something is wrong)

# %% [markdown]
# **Задание 2. Выведите первые 20 строчек датафрейма `data` на экран.**

# %%
data.head(20)
# Out:
#     children  days_employed  dob_years            education  education_id  \
# 0          1   -8437.673028         42               высшее             0
# 1          1   -4024.803754         36              среднее             1
# 2          0   -5623.422610         33              Среднее             1
# 3          3   -4124.747207         32              среднее             1
# 4          0  340266.072047         53              среднее             1
# 5          0    -926.185831         27               высшее             0
# 6          0   -2879.202052         43               высшее             0
# 7          0    -152.779569         50              СРЕДНЕЕ             1
# 8          2   -6929.865299         35               ВЫСШЕЕ             0
# 9          0   -2188.756445         41              среднее             1
# 10         2   -4171.483647         36               высшее             0
# 11         0    -792.701887         40              среднее             1
# ...

# %% [markdown]
# **Задание 3. Выведите основную информацию о датафрейме с помощью метода `info()`.**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Удаление пропусков

# %% [markdown]
# **Задание 4. Выведите количество пропущенных значений для каждого столбца. Используйте комбинацию двух методов.**

# %%
data.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-811a2046da5d> in <module>
# ----> 1 data.isna().sum()
#
# NameError: name 'data' is not defined

# %% [markdown]
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
#
# Удобно было бы сразу вывести долю пропусков. Так мы увидим, что можно отбросить, а с чем надо работать. Пример кода:
#
#     pd.DataFrame(data.isna().mean()*100).style.set_precision(1).background_gradient('coolwarm')

# %% [markdown]
# **Задание 5. В двух столбцах есть пропущенные значения. Один из них — `days_employed`. Пропуски в этом столбце вы обработаете на следующем этапе. Другой столбец с пропущенными значениями — `total_income` — хранит данные о доходах. На сумму дохода сильнее всего влияет тип занятости, поэтому заполнить пропуски в этом столбце нужно медианным значением по каждому типу из столбца `income_type`. Например, у человека с типом занятости `сотрудник` пропуск в столбце `total_income` должен быть заполнен медианным доходом среди всех записей с тем же типом.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['total_income'].isna()), 'total_income'] = \
    data.loc[(data['income_type'] == t), 'total_income'].median()

# %% [markdown]
# ### Обработка аномальных значений

# %% [markdown]
# **Задание 6. В данных могут встречаться артефакты (аномалии) — значения, которые не отражают действительность и появились по какой-то ошибке. таким артефактом будет отрицательное количество дней трудового стажа в столбце `days_employed`. Для реальных данных это нормально. Обработайте значения в этом столбце: замените все отрицательные значения положительными с помощью метода `abs()`.**

# %%
data['days_employed'] = data['days_employed'].abs()

# %% [markdown]
# **Задание 7. Для каждого типа занятости выведите медианное значение трудового стажа `days_employed` в днях.**

# %%
data.groupby('income_type')['days_employed'].agg('median')
# Out:
# income_type
# безработный        366413.652744
# в декрете            3296.759962
# госслужащий          2689.137274
# компаньон            1555.947387
# пенсионер          365286.622650
# предприниматель       520.848083
# сотрудник            1572.328285
# студент               578.751554
# Name: days_employed, dtype: float64

# %% [markdown]
# У двух типов (безработные и пенсионеры) получатся аномально большие значения. Исправить такие значения сложно, поэтому оставьте их как есть.

# %% [markdown]
# **Задание 8. Выведите перечень уникальных значений столбца `children`.**

# %%
data['children'].unique()
# Out:
# array([1, 0, 3, 2, 4, 5])

# %% [markdown]
# **Задание 9. В столбце `children` есть два аномальных значения. Удалите строки, в которых встречаются такие аномальные значения из датафрейма `data`.**

# %%
data = data[(data['children'] != -1) & (data['children'] != 20)]

# %% [markdown]
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Сейчас доля аномалий мала и ни на что не повлияет. В следующий раз старайся сразу высчитывать их долю. Мы можем удалить не больше 5-10% датафрейма. Если доля удаляемых данных больше, надо обрабатывать их по-иному

# %% [markdown]
# **Задание 10. Ещё раз выведите перечень уникальных значений столбца `children`, чтобы убедиться, что артефакты удалены.**

# %%
data['children'].unique()
# Out:
# array([1, 0, 3, 2, 4, 5])

# %% [markdown]
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
#
#
# Можно было бы еще обработать странное значение в данных пола. Оно единично и ни на что не повлияет, но описать его следует

# %% [markdown]
# ### Удаление пропусков (продолжение)

# %% [markdown]
# **Задание 11. Заполните пропуски в столбце `days_employed` медианными значениями по каждого типа занятости `income_type`.**

# %%
for t in data['income_type'].unique():
    data.loc[(data['income_type'] == t) & (data['days_employed'].isna()), 'days_employed'] = \
    data.loc[(data['income_type'] == t), 'days_employed'].median()

# %% [markdown]
# **Задание 12. Убедитесь, что все пропуски заполнены. Проверьте себя и ещё раз выведите количество пропущенных значений для каждого столбца с помощью двух методов.**

# %%
data.isna().sum()
# Out:
# children                 0
# days_employed            0
# dob_years                0
# education                0
# education_id             0
# family_status            0
# family_status_id         0
# gender                   0
# income_type              0
# debt                     0
# total_income             0
# purpose                  0
# total_income_category    0
# purpose_category         0
# dtype: int64

# %% [markdown]
# ### Изменение типов данных

# %% [markdown]
# **Задание 13. Замените вещественный тип данных в столбце `total_income` на целочисленный с помощью метода `astype()`.**

# %%
data['total_income'] = data['total_income'].astype(int)

# %% [markdown]
# ### Обработка дубликатов

# %% [markdown]
# **Задание 14. Обработайте неявные дубликаты в столбце `education`. В этом столбце есть одни и те же значения, но записанные по-разному: с использованием заглавных и строчных букв. Приведите их к нижнему регистру.**

# %%
data['education'] = data['education'].str.lower()

# %% [markdown]
# **Задание 15. Выведите на экран количество строк-дубликатов в данных. Если такие строки присутствуют, удалите их.**

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data = data.drop_duplicates()

# %% [markdown]
# ### Категоризация данных

# %% [markdown]
# **Задание 16. На основании диапазонов, указанных ниже, создайте в датафрейме `data` столбец `total_income_category` с категориями:**
#
# - 0–30000 — `'E'`;
# - 30001–50000 — `'D'`;
# - 50001–200000 — `'C'`;
# - 200001–1000000 — `'B'`;
# - 1000001 и выше — `'A'`.
#
#
# **Например, кредитополучателю с доходом 25000 нужно назначить категорию `'E'`, а клиенту, получающему 235000, — `'B'`. Используйте собственную функцию с именем `categorize_income()` и метод `apply()`.**

# %%
def categorize_income(income):
    try:
        if 0 <= income <= 30000:
            return 'E'
        elif 30001 <= income <= 50000:
            return 'D'
        elif 50001 <= income <= 200000:
            return 'C'
        elif 200001 <= income <= 1000000:
            return 'B'
        elif income >= 1000001:
            return 'A'
    except:
        pass

# %%
data['total_income_category'] = data['total_income'].apply(categorize_income)

# %% [markdown]
# **Задание 17. Выведите на экран перечень уникальных целей взятия кредита из столбца `purpose`.**

# %%
data['purpose'].unique()
# Out:
# array(['покупка жилья', 'приобретение автомобиля',
#        'дополнительное образование', 'сыграть свадьбу',
#        'операции с жильем', 'образование', 'на проведение свадьбы',
#        'покупка жилья для семьи', 'покупка недвижимости',
#        'покупка коммерческой недвижимости', 'покупка жилой недвижимости',
#        'строительство собственной недвижимости', 'недвижимость',
#        'строительство недвижимости', 'на покупку подержанного автомобиля',
#        'на покупку своего автомобиля',
#        'операции с коммерческой недвижимостью',
#        'строительство жилой недвижимости', 'жилье',
#        'операции со своей недвижимостью', 'автомобили',
#        'заняться образованием', 'сделка с подержанным автомобилем',
#        'получение образования', 'автомобиль', 'свадьба',
#        'получение дополнительного образования', 'покупка своего жилья',
#        'операции с недвижимостью', 'получение высшего образования',
#        'свой автомобиль', 'сделка с автомобилем',
# ...

# %% [markdown]
# **Задание 18. Создайте функцию, которая на основании данных из столбца `purpose` сформирует новый столбец `purpose_category`, в который войдут следующие категории:**
#
# - `'операции с автомобилем'`,
# - `'операции с недвижимостью'`,
# - `'проведение свадьбы'`,
# - `'получение образования'`.
#
# **Например, если в столбце `purpose` находится подстрока `'на покупку автомобиля'`, то в столбце `purpose_category` должна появиться строка `'операции с автомобилем'`.**
#
# **Используйте собственную функцию с именем `categorize_purpose()` и метод `apply()`. Изучите данные в столбце `purpose` и определите, какие подстроки помогут вам правильно определить категорию.**

# %%
def categorize_purpose(row):
    try:
        if 'автом' in row:
            return 'операции с автомобилем'
        elif 'жил' in row or 'недвиж' in row:
            return 'операции с недвижимостью'
        elif 'свад' in row:
            return 'проведение свадьбы'
        elif 'образов' in row:
            return 'получение образования'
    except:
        return 'нет категории'

# %%
data['purpose_category'] = data['purpose'].apply(categorize_purpose)

# %% [markdown]
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Каждый шаг работы стоит заканчивать кратким выводом.

# %% [markdown]
# ### Шаг 3. Исследуйте данные и ответьте на вопросы

# %% [markdown]
# #### 3.1 Есть ли зависимость между количеством детей и возвратом кредита в срок?

# %%
# решение задачи без использвания функции:
""""
child_stat = data.groupby('children').agg({'debt':['count', 'sum', 'mean']})
child_stat.columns = ['Всего кредитополучателей', 'Всего должников', 'Доля должников']
child_stat = child_stat[0:3] 
child_stat"""

def calculation_debt(a):
    b = data.groupby(a).agg({'debt':['count', 'sum', 'mean']})
    b.columns = ['Всего кредитополучателей', 'Всего должников', 'Доля должников']
    return b
child_stat = calculation_debt(data['children'])
child_stat = child_stat[child_stat['Всего кредитополучателей'] > 500]
child_stat.round(2)
# Out:
#           Всего кредитополучателей  Всего должников  Доля должников
# children
# 0                            14091             1063            0.08
# 1                             4808              444            0.09
# 2                             2052              194            0.09

# %% [markdown]
# <p>
# <div class="alert-info">
#
# **Вывод:(изм.)** Количество детей прямопропорционально влияет на на возврат кредита в срок (чем больше детей, тем выше вероятность просрочики кредита). Так как показатели выборки для групп с 3-мя и более детьми слишком низкие, их исключил из расчета.

# %% [markdown]
# <p>
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
#
#
# - Расчет доли верный! Для того, чтобы оценить размеры групп, стоит вывести количество кредитополучателей в группе и количество должников. После `groupby()` можно указать так: `data.groupby('children').agg({'debt':['count', 'sum', 'mean']})`
#
# - Выявить зависимость можно сравнив только самые большие выборки с 0, 1 и 2 детьми.
#
# - Здесь долю должников можно сразу вывести в сводную таблицу используя `mean`.
#
# - Для того, чтобы таблица смотрелась лучше стоит переименовать столбцы, вот пример кода, как это можно сделать:
#
#
#     data.columns = ['Всего кредитополучателей', 'Всего должников', 'Доля должников']
#
# - Можно сделать универсальную функцию для этого и следущих пунктов.

# %% [markdown]
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера 2 ✔️</b>
#
#
# Отлично 👍 Чтобы не перегружать проект лучше удалять не используемый код, а не оставлять закомментированный </div>

# %% [markdown]
# #### 3.2 Есть ли зависимость между семейным положением и возвратом кредита в срок?

# %%
# Ваш код будет здесь. Вы можете создавать новые ячейки.
# Проделываем то же самое по столбцу 'family_status', но уже применим специальную функцию .mean()
#family_stat = data.groupby('family_status')['debt'].mean()*100
#family_stat.sort_values().round(2)
family_stat = calculation_debt(data['family_status'])
family_stat.sort_values('Доля должников').round(2)
# Out:
#                        Всего кредитополучателей  Всего должников  \
# family_status
# вдовец / вдова                              951               63
# в разводе                                  1189               84
# женат / замужем                           12261              927
# гражданский брак                           4134              385
# Не женат / не замужем                      2796              273
#
#                        Доля должников
# family_status
# вдовец / вдова                   0.07
# в разводе                        0.07
# женат / замужем                  0.08
# гражданский брак                 0.09
# Не женат / не замужем            0.10

# %% [markdown]
# **Вывод:** Наблюдается зависмость от семейного положения. "Лучшие" показатели у групп `вдовец / вдова` и `в разводе`, что наверняка связано с приобретенным непростым жизненным опытом. Для группы `Не женат / не замужем` наблюдается более легкомысленное отношение к финансовым обязательствам.

# %% [markdown]
# <p>
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
#
#
# Согласна, по расчетам можно вывести общую зависимость, что заемщики состоящие или состоявшие в браке лучше выплачивают кредиты. Нужно сделать сводную таблицу, где помимо доли, так же посчитать размеры групп и количество должников.

# %% [markdown]
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера 2 ✔️</b>
#
#
# 👍</div>

# %% [markdown]
# #### 3.3 Есть ли зависимость между уровнем дохода и возвратом кредита в срок?

# %%
# Ваш код будет здесь. Вы можете создавать новые ячейки.
#data
#total_income_stat = data.groupby('total_income_category')['debt'].mean()*100
#total_income_stat.sort_values().round(2)

total_income_stat = calculation_debt(data['total_income_category'])
total_income_stat = total_income_stat[total_income_stat['Всего кредитополучателей'] > 500]
total_income_stat.sort_values('Доля должников').round(2)
# Out:
#                        Всего кредитополучателей  Всего должников  \
# total_income_category
# B                                          5014              354
# C                                         15921             1353
#
#                        Доля должников
# total_income_category
# B                                0.07
# C                                0.08

# %% [markdown]
# <p>
# <div class="alert-info">
#
# **Вывод:** . Согласно полученным данным, можно утверждать, что чем выше уровень заработка, тем меньше процент просрочки по кредиту.

# %% [markdown]
# <p>
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
#
# Здесь нужно обратить внимание, что выборки крайне несбалансированны и для выявления зависимости стоит сравнить две самые большие категории B и C.
#
#
# Нужно сделать сводную таблицу, где помимо доли, так же посчитать размеры групп и количество должников.

# %% [markdown]
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера 2 ✔️</b>
#
#
# 👍</div>

# %% [markdown]
# #### 3.4 Как разные цели кредита влияют на его возврат в срок?

# %%
# Ваш код будет здесь. Вы можете создавать новые ячейки.
#purpose_stat = data.groupby('purpose_category')['debt'].mean()*100
#purpose_stat.sort_values().round(2)

purpose_stat = calculation_debt(data['purpose_category'])
purpose_stat.sort_values('Доля должников').round(2)
# Out:
#                           Всего кредитополучателей  Всего должников  \
# purpose_category
# операции с недвижимостью                     10751              780
# проведение свадьбы                            2313              183
# получение образования                         3988              369
# операции с автомобилем                        4279              400
#
#                           Доля должников
# purpose_category
# операции с недвижимостью            0.07
# проведение свадьбы                  0.08
# получение образования               0.09
# операции с автомобилем              0.09

# %% [markdown]
# **Вывод:** Согласно данным, кредитование категории `операции недвижимости` несет меньше рисков чем `операции с автомобилем`.

# %% [markdown]
# <p>
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
#
# Верно! Нужно сделать сводную таблицу, где помимо доли, так же посчитать размеры групп и количество должников.

# %% [markdown]
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера 2 ✔️</b>
#
#
# 👍</div>

# %% [markdown]
# #### 3.5 Приведите возможные причины появления пропусков в исходных данных.

# %% [markdown]
# *Ответ:* В исходных данных пропуски были в `days_employed` и `total_income`.
#
# Возможные причина - ошибка при выгрузке данных, в таких случаях можно обратиться к отвественному разработчику.
# Данную причину нельзя отнести к случайным пропускам, т.к. они встречаются только в двух столбцах.

# %% [markdown]
# <div class="alert-warning">
# <b>Комментарий ревьюера ⚠️</b>
#
#
# Помимо технических ошибок: неправильный запрос к БД, некорректная выгрузка и т.п., не стоит исключать и человеческого фактора: кто-то что-то не ввел, умышленно или нет.

# %% [markdown]
# #### 3.6 Объясните, почему заполнить пропуски медианным значением — лучшее решение для количественных переменных.

# %% [markdown]
# *Ответ:* Потому что это более объективная информация, в данном проекте брали медиану по категорям занятости. В зависимости от категории значения сильно отличаются, что не может дать корректной оценки. Считать среднее по доходам стедентов и предпринимателей никоим образом не даст корректных данных.

# %% [markdown]
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера ✔️</b>
#
# Действительно, в данных могут наблюдаться некоторые "выбросы", и даже небольшое их количество может сильно "перетягивать" среднее значение в большую или меньшую сторону. Медиана зачастую даёт более правдивую картину. Также важно в каждом случае смотреть на то, как распределены данные.
# </div>

# %% [markdown]
# ### Шаг 4: общий вывод.

# %% [markdown]
# Поступила задача от заказчика - кредитного отдела банка. Нужно разобраться, влияет ли семейное положение и количество детей клиента на факт погашения кредита в срок. Были предоставлены входные данные от банка — статистика о платёжеспособности клиентов в формате csv. `/datasets/data.csv`.
# 1. На начальном этапе были изучены предоставленные данные.
# 2. После изучения обнаружил пропуски в данных и некорректные данные.
# 3. Пропуски заменил медианными значениями, предварительно сгруппировав данные по категориии - тип занятости, так как эта категория наиболее полно отображает данные.
# 4. Исправил некорретные данные:
#         а - в столбце `days_employed` были отрицательные значения
#         б - в столбце `children` были отрицательные и выходящие за границу (до 18 лет) значения.
# 5. Удалил повторяющиеся значения.
# 6. Сгруппировал данные в таблице по категориям:
#         а - создал категорию по размеру дохода `'total_income_category'`
#         б - создал категорию по цели кредитования `'purpose_category'`
# 7. После предобработки данных провел исследования согласно задания.
# 8. Результаты исследования, на которые следует обратить внимание приведены ниже:

# %% [markdown]
# #### Зависимость между количеством детей и возвратом кредита:

# %%
child_stat.round(2)
# Out:
#           Всего кредитополучателей  Всего должников  Доля должников
# children
# 0                            14091             1063            0.08
# 1                             4808              444            0.09
# 2                             2052              194            0.09

# %% [markdown]
# #### Зависимость между семейным положением и возвратом кредита:

# %%
family_stat.sort_values('Доля должников').round(2)
# Out:
#                        Всего кредитополучателей  Всего должников  \
# family_status
# вдовец / вдова                              951               63
# в разводе                                  1189               84
# женат / замужем                           12261              927
# гражданский брак                           4134              385
# Не женат / не замужем                      2796              273
#
#                        Доля должников
# family_status
# вдовец / вдова                   0.07
# в разводе                        0.07
# женат / замужем                  0.08
# гражданский брак                 0.09
# Не женат / не замужем            0.10

# %% [markdown]
# #### Зависимость между уровнем дохода и возвратом кредита:

# %%
total_income_stat.sort_values('Доля должников').round(2)
# где "B" - это категория дохода от 200001–1000000,
# а 'C' - это категория дохода от 50001–200000
# Out:
#                        Всего кредитополучателей  Всего должников  \
# total_income_category
# B                                          5014              354
# C                                         15921             1353
#
#                        Доля должников
# total_income_category
# B                                0.07
# C                                0.08

# %% [markdown]
# #### Зависимость между целью кредита и его возвратом:

# %%
purpose_stat.sort_values('Доля должников').round(2)
# Out:
#                           Всего кредитополучателей  Всего должников  \
# purpose_category
# операции с недвижимостью                     10751              780
# проведение свадьбы                            2313              183
# получение образования                         3988              369
# операции с автомобилем                        4279              400
#
#                           Доля должников
# purpose_category
# операции с недвижимостью            0.07
# проведение свадьбы                  0.08
# получение образования               0.09
# операции с автомобилем              0.09

# %% [markdown]
# <p>
# <div class="alert-danger">
# <b>Комментарий ревьюера ❌</b>
#
# Вывод - это полный отчет о проделанной работе. Он должен содержать все: от обработки данных до рекомендаций заказчику. Я бы советовала в начале кратко описывать, с какими данными мы работали и что сделали, а затем отвечать на вопрос исследования - в нашем случае, рекомендовать заказчику, как формировать модель кредитного скоринга

# %% [markdown]
# <p>
# <div class="alert-success">
# <b>Комментарий ревьюера 2 ✔️</b>
#
#
# Отлично 👍</div>

# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# **Общий вывод по проекту**
#
# Станислав, спасибо за проделанную работу. Мне понравился твой подход и в целом код работает верно. Есть несколько важных моментов, которые я отметила и которые можно было бы улучшить, подсказки ты найдешь в моих комментариях.
#
#
# **Что нужно переделать, чтобы я приняла твой проект🤓**:
#
# * Сделать сводные таблицы в каждом пункте с расчётами, куда добавить размеры групп и количество должников.
# * Обрати внимание, что выборки по уровню дохода крайне несбалансированны и для выявления зависимости стоит сравнить две самые большие категории B и C.
# * Дополнить общий вывод
#
#
# **Рекомендации ты найдешь в моих комментариях!**
#
# Полезная ссылка про графики:
#
# https://habr.com/ru/post/468295/
#
# и еще одна
#
# https://pyprog.pro/mpl/mpl_short_guide.html
#
#
# **Желаю удачи и жду твой проект на повторное ревью!**😉

# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# **Общий вывод по проекту 2**
#
# Станислав, поздравляю со сдачей проекта!  🎉 🎉 🎉
#
# Советую тебе бесплатный курс по статистике, можно посмотреть отдельно интересующие тебя темы:
#
# https://stepik.org/course/76/
